# %%
import pandas as pd

df = pd.read_csv("../data/raw/all_games_1024.csv")

print(df.shape)
print(df.columns)
df.head()
# Out:
# (290826, 22)
# Index(['thrower', 'thrower_x', 'thrower_y', 'receiver', 'receiver_x',
#        'receiver_y', 'turnover', 'possession_num', 'possession_throw',
#        'game_quarter', 'quarter_point', 'is_home_team', 'home_team_score',
#        'away_team_score', 'gameID', 'total_points', 'home_teamID',
#        'away_teamID', 'current_line', 'times', 'home_team_win', 'score_diff'],
#       dtype='str')
#    thrower  thrower_x  thrower_y receiver  receiver_x  receiver_y  turnover  \
# 0  jnissen       1.02      15.14   jmalks       -8.17       23.51         0
# 1   jmalks      -8.17      23.51  jnissen        2.18       27.08         0
# 2  jnissen       2.18      27.08   jmalks      -10.21       33.56         0
# 3   jmalks     -10.21      33.56  jnissen       -3.94       26.79         0
# 4  jnissen      -3.94      26.79    boort       12.96       36.26         0
#
#    possession_num  possession_throw  game_quarter  ...  home_team_score  \
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 290826 entries, 0 to 290825
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   thrower           290826 non-null  str
#  1   thrower_x         290826 non-null  float64
#  2   thrower_y         290826 non-null  float64
#  3   receiver          273936 non-null  str
#  4   receiver_x        290826 non-null  float64
#  5   receiver_y        290826 non-null  float64
#  6   turnover          290826 non-null  int64
#  7   possession_num    290826 non-null  int64
#  8   possession_throw  290826 non-null  int64
#  9   game_quarter      290826 non-null  int64
#  10  quarter_point     290826 non-null  int64
#  11  is_home_team      290826 non-null  bool
#  12  home_team_score   290826 non-null  int64
#  13  away_team_score   290826 non-null  int64
#  14  gameID            290826 non-null  str
#  15  total_points      290826 non-null  int64
# ...

# %%
from ufa import get_games_since_2024

games = get_games_since_2024()
games.head()
# Out:
#                gameID awayTeamID homeTeamID  awayScore  homeScore status  \
# 0  2024-04-26-MTL-BOS      royal      glory         17         19  Final
# 1  2024-04-26-DAL-HTX     legion      havoc         21         26  Final
# 2   2024-04-27-SD-SEA   growlers   cascades         14         28  Final
# 3   2024-04-27-MTL-NY      royal     empire         16         18  Final
# 4  2024-04-27-ATL-CAR     hustle     flyers         16         24  Final
#
#               startTimestamp startTimezone  \
# 0  2024-04-26T19:00:00-04:00           EDT
# 1  2024-04-26T19:30:00-05:00           CDT
# 2  2024-04-27T14:00:00-07:00           PDT
# 3  2024-04-27T17:00:00-04:00           EDT
# 4  2024-04-27T18:00:00-04:00           EDT
#
#                                         streamingURL  \
# 0  https://www.watchufa.tv/videos/montreal-at-bos...
# 1  https://www.watchufa.tv/videos/dallas-at-houst...
# 2  https://www.watchufa.tv/videos/san-diego-at-se...
# ...

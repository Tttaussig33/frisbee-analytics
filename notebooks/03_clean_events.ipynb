# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
SRC_PATH = PROJECT_ROOT / "src"

sys.path.append(str(SRC_PATH))

# %%
from ufa.client import get_games, get_game_events
from ufa.clean import clean_game_events
from ufa.metrics import calculate_thrower_stats
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ufa.client import get_games, get_game_events
#       2 from ufa.clean import clean_game_events
#       3 from ufa.metrics import calculate_thrower_stats
#
# ImportError: cannot import name 'get_games' from 'ufa.client' (c:\Users\htaus\Desktop\Ultimate Frisbee Analytics\src\ufa\client.py)

# %%
games = get_games()

game_id = games.loc[0, "gameID"]

events = get_game_events(game_id)

throws = clean_game_events(events)

player_stats = calculate_thrower_stats(throws)

player_stats.sort_values("attempts", ascending=False).head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 games = get_games()
#       2
#       3 game_id = games.loc[0, "gameID"]
#       4
#
# NameError: name 'get_games' is not defined
